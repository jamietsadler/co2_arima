# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn

# %%
df = pd.read_csv('datasets/CO2.csv', index_col=0)

# %%
df.head()
# Out:
#             CO2_ppm
# date
# 1958-03-01   315.71
# 1958-04-01   317.45
# 1958-05-01   317.50
# 1958-06-01   317.10
# 1958-07-01   315.86

# %%
df.describe()
# Out:
#           CO2_ppm
# count  727.000000
# mean   353.640702
# std     27.443136
# min    312.660000
# 25%    328.555000
# 50%    351.310000
# 75%    375.700000
# max    411.240000

# %%
df.plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %% [markdown]
# Non Stationary dataset, need to convert into stationary to use arima modelling

# %%
changes = df.pct_change()

# %%
changes.head()
# Out:
#              CO2_ppm
# date
# 1958-03-01       NaN
# 1958-04-01  0.005511
# 1958-05-01  0.000158
# 1958-06-01 -0.001260
# 1958-07-01 -0.003910

# %%
from statsmodels.tsa.stattools import acf
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %%
plot_acf(df['CO2_ppm'], lags=100)

# %%
from statsmodels.tsa.stattools import adfuller

# %%
result = adfuller(df['CO2_ppm'])

# %%
# Print test statistic
print(result[0])

# Print p-value
print(result[1])

# Print critical values
print(result[4])
# Out:
# 4.774866785205469
# 1.0
# {'1%': -3.439646367660705, '5%': -2.8656425177031375, '10%': -2.5689546724554404}

# %% [markdown]
# Test Statistic & p-value are very high, not stationary

# %%
df_diff = df.diff().dropna()

# %%
df_diff.head()
# Out:
#             CO2_ppm
# date
# 1958-04-01     1.74
# 1958-05-01     0.05
# 1958-06-01    -0.40
# 1958-07-01    -1.24
# 1958-08-01    -0.93

# %%
result2 = adfuller(df_diff['CO2_ppm'])

# %%
# Print test statistic
print(result2[0])

# Print p-value
print(result2[1])

# Print critical values
print(result2[4])
# Out:
# -5.287425631615295
# 5.813789175331615e-06
# {'1%': -3.4396596024765795, '5%': -2.86564834926679, '10%': -2.568957779286756}

# %% [markdown]
# p-value now extremely low and time series is stationary

# %%
df_diff.plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
plot_acf(df_diff['CO2_ppm'])

# %%
plot_pacf(df_diff['CO2_ppm'])

# %%
co2_train = df.iloc[:int(len(df)*0.8)]
co2_ttest = df.iloc[int(len(df)*0.8):]

# %%
import pmdarima as pmd

# %%
results = pmd.auto_arima(df,
                        seasonal=True,
                        m=12)
# Out:
# /Users/jamiesadler/opt/anaconda3/lib/python3.8/site-packages/pmdarima/arima/_auto_solvers.py:522: ModelFitWarning: Error fitting  ARIMA(3,1,1)(1,0,1)[12]           (if you do not want to see these warnings, run with error_action="ignore").
# Traceback:
# Traceback (most recent call last):
#   File "/Users/jamiesadler/opt/anaconda3/lib/python3.8/site-packages/pmdarima/arima/_auto_solvers.py", line 506, in _fit_candidate_model
#     fit.fit(y, X=X, **fit_params)
#   File "/Users/jamiesadler/opt/anaconda3/lib/python3.8/site-packages/pmdarima/arima/arima.py", line 482, in fit
#     self._fit(y, X, **fit_args)
#   File "/Users/jamiesadler/opt/anaconda3/lib/python3.8/site-packages/pmdarima/arima/arima.py", line 403, in _fit
#     fit, self.arima_res_ = _fit_wrapper()
#   File "/Users/jamiesadler/opt/anaconda3/lib/python3.8/site-packages/pmdarima/arima/arima.py", line 393, in _fit_wrapper
#     return arima, arima.fit(start_params=start_params,
# ...

# %%
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                      SARIMAX Results
# ...
# Dep. Variable:                                  y   No. Observations:                  727
# Model:             SARIMAX(2, 1, 1)x(1, 0, 1, 12)   Log Likelihood                -204.586
# Date:                            Fri, 21 May 2021   AIC                            421.172
# Time:                                    16:55:07   BIC                            448.697
# Sample:                                         0   HQIC                           431.794
#                                             - 727
# Covariance Type:                              opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.3549      0.085      4.185      0.000       0.189       0.521
# ar.L2          0.0879      0.018      4.997      0.000       0.053       0.122
# ...

# %%
results.plot_diagnostics()

# %% [markdown]
# Good stuff

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX

# %%
model = SARIMAX(df, order=(0,0,3), seasonal_order=(1,0,1,12))
# Out:
# /Users/jamiesadler/opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/jamiesadler/opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'

# %%
sarima_results = model.fit()
# Out:
# /Users/jamiesadler/opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /Users/jamiesadler/opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:997: UserWarning: Non-stationary starting seasonal autoregressive Using zeros as starting parameters.
#   warn('Non-stationary starting seasonal autoregressive'
# /Users/jamiesadler/opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
sarima_pred = sarima_results.get_forecast(steps=25)
sarima_mean = sarima_pred.predicted_mean
